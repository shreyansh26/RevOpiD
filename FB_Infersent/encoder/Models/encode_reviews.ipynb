# %%
# import stuff
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

from random import randint
import matplotlib

import numpy as np
import torch

GLOVE_PATH = '../dataset/GloVe/glove.840B.300d.txt'

# %% [markdown]
# # Load model

# %%
model = torch.load('infersent.allnli.pickle', map_location=lambda storage, loc: storage)
# On CPU, setting the right number of threads with "torch.set_num_threads(k)" may improve performance

# %%
model.set_glove_path(GLOVE_PATH)

# %%
model.build_vocab_k_words(K=100000)
# Out:
# Vocab size : 100000

# %% [markdown]
# # Load sentences

# %%
# Load sentences
sentences = []
indi_sent_rev = []
with open('text_0_AutomotiveProd7.txt') as f:
    i = 1
    rev_num = -1
    for line in f:
        if i == 1:
            rev_num += 1
            l = line.strip()
            indi_sent = l.split('.')
            indi_sent = [a.strip() for a in indi_sent]
            indi_sent = list(filter(None, indi_sent))
            for k in range(len(indi_sent)):
                indi_sent_rev.append(rev_num)
            sentences.extend(indi_sent)
            i *= -1
        else:
            i *= -1
print(len(sentences))
# Out:
# 382

# %%
sentences[:5]
# Out:
# ['Much needed tool for anyone that has a truck',
#  'Fits in any location and allows you to store equipment securely',
#  'I have a 2007 Tacoma that I broke the tailgate on, so as a temporary repair I got a tailgate net and one of these bars to help prevent bed flex and also for when there was stuff in the bed',
#  'Ratchet mechanism took all of 30 seconds to figure out',
#  'Works fine install took maybe 1 minute, and it stays in place']

# %% [markdown]
# # Encode sentences

# %%
embeddings = model.encode(sentences, bsize=128, tokenize=False, verbose=True)
print('nb sentences encoded : {0}'.format(len(embeddings)))
# Out:
# Nb words kept : 5656/5982 (94.55 %)
# Speed : 47.38 sentences/s (cpu mode, bsize=128)
# nb sentences encoded : 382

# %%
print(embeddings.shape)
# Out:
# (382, 4096)

# %% [markdown]
# # Visualization

# %%
np.linalg.norm(model.encode([sentences[0]]))
# Out:
# 3.7739689

# %%
def cosine(u, v):
    return np.dot(u, v) / (np.linalg.norm(u) * np.linalg.norm(v))

# %%
model.encode([sentences[0]])[0]
# Out:
# array([ 0.04275879,  0.04914635,  0.05915082, ..., -0.00428127,
#        -0.03567129,  0.05815831], dtype=float32)

# %%
cosine(model.encode([sentences[0]])[0], model.encode([sentences[3]])[0])
# Out:
# 0.52351725

# %%
sentences[0]
# Out:
# 'Much needed tool for anyone that has a truck'

# %%
sentences[3]
# Out:
# 'Ratchet mechanism took all of 30 seconds to figure out'

# %%
f = open('infersent_results.txt', 'w')
for i in range(len(sentences)):
    cosine_for_one = []
    for j in range(len(sentences)):
        if i != j:
            cosine_for_one.append([cosine(model.encode([sentences[i]])[0], model.encode([sentences[j]])[0]), i, j])
    cosine_for_one = sorted(cosine_for_one, reverse=True)
    #print(cosine_for_one)
    top_similar = cosine_for_one[:5]
    f.write('Similar to review '+str(i+1)+' - '+sentences[i]+" :\n")
    for ind, k in enumerate(top_similar):
        f.write(str(ind+1) + '. ' + str(k[0]) + ' ' + sentences[k[2]]+'\n')
    f.write('\n')
    print('Review '+str(i)+' done.')
f.close()
# Out:
# Review 0 done.
# Review 1 done.
# Review 2 done.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-516cbf7aa516> in <module>()
#       4     for j in range(len(sentences)):
#       5         if i != j:
# ----> 6             cosine_for_one.append([cosine(model.encode([sentences[i]])[0], model.encode([sentences[j]])[0]), i, j])
#       7     cosine_for_one = sorted(cosine_for_one, reverse=True)
#       8     #print(cosine_for_one)
#
# ~/Desktop/RevOpiD/InferSent/InferSent-master/encoder/models.py in encode(self, sentences, bsize, tokenize, verbose)
#     205                 batch = batch.cuda()
#     206             batch = self.forward(
# --> 207                 (batch, lengths[stidx:stidx + bsize])).data.cpu().numpy()
#     208             embeddings.append(batch)
#     209         embeddings = np.vstack(embeddings)
#
# ~/Desktop/RevOpiD/InferSent/InferSent-master/encoder/models.py in forward(self, sent_tuple)
#      51         # Handling padding in Recurrent Networks
#      52         sent_packed = nn.utils.rnn.pack_padded_sequence(sent, sent_len)
# ---> 53         sent_output = self.enc_lstm(sent_packed)[0]  # seqlen x batch x 2*nhid
#      54         sent_output = nn.utils.rnn.pad_packed_sequence(sent_output)[0]
#      55
#
# /usr/local/lib/python3.5/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     222         for hook in self._forward_pre_hooks.values():
#     223             hook(self, input)
# --> 224         result = self.forward(*input, **kwargs)
#     225         for hook in self._forward_hooks.values():
#     226             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.5/dist-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     160             flat_weight=flat_weight
#     161         )
# --> 162         output, hidden = func(input, self.all_weights, hx)
#     163         if is_packed:
#     164             output = PackedSequence(output, batch_sizes)
#
# /usr/local/lib/python3.5/dist-packages/torch/nn/_functions/rnn.py in forward(input, *fargs, **fkwargs)
#     349         else:
#     350             func = AutogradRNN(*args, **kwargs)
# --> 351         return func(input, *fargs, **fkwargs)
#     352
#     353     return forward
#
# /usr/local/lib/python3.5/dist-packages/torch/nn/_functions/rnn.py in forward(input, weight, hidden)
#     242             input = input.transpose(0, 1)
#     243
# --> 244         nexth, output = func(input, hidden, weight)
#     245
#     246         if batch_first and batch_sizes is None:
#
# /usr/local/lib/python3.5/dist-packages/torch/nn/_functions/rnn.py in forward(input, hidden, weight)
#      82                 l = i * num_directions + j
#      83
# ---> 84                 hy, output = inner(input, hidden[l], weight[l])
#      85                 next_hidden.append(hy)
#      86                 all_output.append(output)
#
# /usr/local/lib/python3.5/dist-packages/torch/nn/_functions/rnn.py in forward(input, hidden, weight)
#     155                 hidden = (inner(step_input, hidden[0], *weight),)
#     156             else:
# --> 157                 hidden = inner(step_input, hidden, *weight)
#     158
#     159             output.append(hidden[0])
#
# /usr/local/lib/python3.5/dist-packages/torch/nn/_functions/rnn.py in LSTMCell(input, hidden, w_ih, w_hh, b_ih, b_hh)
#      29
#      30     hx, cx = hidden
# ---> 31     gates = F.linear(input, w_ih, b_ih) + F.linear(hx, w_hh, b_hh)
#      32
#      33     ingate, forgetgate, cellgate, outgate = gates.chunk(4, 1)
#
# /usr/local/lib/python3.5/dist-packages/torch/nn/functional.py in linear(input, weight, bias)
#     551     if input.dim() == 2 and bias is not None:
#     552         # fused op is marginally faster
# --> 553         return torch.addmm(bias, input, weight.t())
#     554
#     555     output = input.matmul(weight.t())
#
# /usr/local/lib/python3.5/dist-packages/torch/autograd/variable.py in addmm(cls, *args)
#     922         @classmethod
#     923         def addmm(cls, *args):
# --> 924             return cls._blas(Addmm, args, False)
#     925
#     926         @classmethod
#
# /usr/local/lib/python3.5/dist-packages/torch/autograd/variable.py in _blas(cls, args, inplace)
#     918             else:
#     919                 tensors = args
# --> 920             return cls.apply(*(tensors + (alpha, beta, inplace)))
#     921
#     922         @classmethod
#
# /usr/local/lib/python3.5/dist-packages/torch/autograd/_functions/blas.py in forward(ctx, add_matrix, matrix1, matrix2, alpha, beta, inplace)
#      24         output = _get_output(ctx, add_matrix, inplace=inplace)
#      25         return torch.addmm(alpha, add_matrix, beta,
# ---> 26                            matrix1, matrix2, out=output)
#      27
#      28     @staticmethod
#
# KeyboardInterrupt:

# %%
f = open('infersent_results_5.txt', 'w')
for i in range(5):
    cosine_for_one = []
    for j in range(len(sentences)):
        if i != j:
            cosine_for_one.append([cosine(model.encode([sentences[i]])[0], model.encode([sentences[j]])[0]), i, j])
    cosine_for_one = sorted(cosine_for_one, reverse=True)
    #print(cosine_for_one)
    top_similar = cosine_for_one[:5]
    f.write('Similar to review '+str(i+1)+' - '+sentences[i]+" :\n")
    for ind, k in enumerate(top_similar):
        f.write(str(ind+1) + '. ' + str(k[0]) + ' ' + sentences[k[2]]+'\n')
    f.write('\n')
    print('Review '+str(i)+' done.')
f.close()
# Out:
# Review 0 done.
# Review 1 done.
# Review 2 done.
# Review 3 done.
# Review 4 done.

# %%
docLabel = []
for i, j in enumerate(indi_sent_rev):
    docLabel.append('sent'+str(i)+'r'+str(j))

# %%
print(docLabel[:10])
# Out:
# ['sent0r0', 'sent1r0', 'sent2r1', 'sent3r1', 'sent4r1', 'sent5r1', 'sent6r1', 'sent7r2', 'sent8r2', 'sent9r2']

# %%
import pandas as pd
from sklearn.cluster import KMeans
## K-means ##
num_clusters = 20
km = KMeans(n_clusters=num_clusters)
km.fit(embeddings)
clusters = km.labels_.tolist()

# %%
## Print Sentence Clusters ##
cluster_info = {'sentence': sentences, 'cluster' : clusters}
sentenceDF = pd.DataFrame(cluster_info, index=[clusters], columns = ['sentence','cluster'])

# %%
for num in range(num_clusters):
    print("Sentence cluster %d: " %int(num+1), end='')
    print()
    #print(sentenceDF.ix[num]['sentence'])
    flag = 0
    i = 1
    for sentence in sentenceDF.ix[num]['sentence']:
        print(str(i)+': '+sentence)
        i += 1
    print()
# Out:
# Sentence cluster 1:
# 1: I have a 2007 Tacoma that I broke the tailgate on, so as a temporary repair I got a tailgate net and one of these bars to help prevent bed flex and also for when there was stuff in the bed
# 2: Just a wee bit tricky to learn to operate at first, blame instructions on one word, instead of saying "rotate" should say "pull over" for the lever, engage last black notch (so easy to miss), then adjust length to short or long quickly
# 3: This was an early Fathers Day gift for my husband, and he couldn't be happier! Easy to use, love the ratchet instead of a twist and lock,held the load in the truck without shifting when we went camping (literally 40 miles of bad road), good pads on ends so truck bed is protected
# 4: So far, no "pinches", either; perhaps I was forewarned by the misadventures of others, but I'm nevertheless cautious!  It grips tightly, and doesn't slip; it packs up to a small, manageable size; what's not to like?  BTW, I'm using this to hold up the folded rear seat of our '13 2-Dr Jeep Wrangler
# 5: I quests your fingers could get caught if you were not paying attention, but you could get hit by a bus for the same reason
# 6: Been a great cargo bar, I use it for holding plastic bins in place in the bed of my truck and so far it has worked great and has never budged unless I have removed it intentionally
# 7: I bought this cargo bar in a hurry to keep our coolers and gas cans in place during our 800 mile death valley off road adventure
# 8: It's a little bit on the flimsy side, but I does section your truck bed out to help keep your groceries from not rolling around back there
# Sentence cluster 2:
# 1: Cannot believe that there are actually some poor reviews
# 2: I'm not really well off so I'm careful with my money
# 3: No regrets from me on this purchase
# 4: Will not hold in place
# 5: It will work, but not as tight as the turn stile
# 6: I have had no problems with it
# 7: It has not failed me yet
# 8: Never had a problem with it slipping or not unlocking or anything
# 9: I do not recommend this cargo bar
# 10: It was unable to stay in the locked position even with no stress being placed on it
# 11: The device is not worth it
# 12: Have had no problems at all
# Sentence cluster 3:
# 1: Bob
# 2: It's useless now
# 3: driver's curse)
# 4: So petty, I know
# 5: One high, one low
# 6: Enjoy
# 7: Super value
# 8: it is still in place and working
# 9: K
# 10: ,
# 11: Would buy again!
# 12: The price is right too
# 13: I ordered two
# 14: One is broken
# 15: Open your box ASAP
# 16: The one works ok
# 17: This, to quote a phrase, is "more better"!
# 18: This product is trash
# 19: I would recommend
# 20: Performs exactly as expected
# 21: I'd buy it again
# 22: Outstanding price
# 23: LOL
# 24: now I need a topper!
# 25: Ends were open
# 26: keep looking
# 27: They work just as described
# 28: A+++++++++++++
# 29: definitely worth the price
# 30: Keeper 05059 Ratcheting Cargo BarSorry  Will S
# 31: New Hampshire
# 32: Thanks
# Sentence cluster 4:
# 1: Fits in any location and allows you to store equipment securely
# 2: Good construction, use it as a cargo separator under my tonneau cover
# 3: It is ok for what it's intended to do, which is be a lightweight cargo divider
# 4: The cargo bar is great
# 5: I was looking for a sturdy, quality made cargo restraint bar and this is not it
# 6: Nice cargo bar for the price
# 7: I thought this cargo bar would be easier to place in a lot let time
# 8: I would recommend trying a different cargo bar
# 9: If your moving anything heavy don't count on this bar
# 10: If you want a quality, heavy duty cargo bar at a good price, this is it
# 11: I've had several different types of cargo retaining mechanisms, but this one works
# 12: Someone recommended a cargo bar and I bought this one
# 13: If you are looking for a heavy duty piece of equipment
# 14: These cargo bars fit it perfectly - no complaints with the quality or operation after a winter of holding cargo
# 15: I'm fairly pleased with this cargo bar
# 16: I`ve owned cargo bars in the past but they were threaded and difficult to extend constently
# 17: I was disappointed in the bar diameter and overall durability
# 18: I would recommend you keep looking for a sturdier cargo bar
# 19: This cargo bar is well made and capable of holding almost any size/weight load in place
# Sentence cluster 5:
# 1: The ratchet increments are wide enough that you may need to test where along the the bed wall the bar can be most effectively tightened
# 2: if I was the designer of this tool, I would have tried to figure out a way to put the ratchet in the middle of the bar
# 3: I just received 2 ratcheting cargo bars and I am just as quickly returning them back to Amazon
# 4: The only con I have is the rubber pads on the ends are too hard and you just can't that last click to get it tight enough to stay in place
# 5: I don't know how good this product will be on holding back heavy items, but it works well on garden flowers they all stead in place with this bar
# 6: I like these bars they are easy to use and stay in place, with the rubber encased feet the hold wherever you install them, they will extend to full width of bed or retract to between wheel wells
# 7: I suspect a slippery plastic bed wall would require more pressure to hold firmly and thus not work as well thus the comments of needing a finer ratchet to make that little bit more extension
# 8: Used to have one of the ones that used threaded rod to unscrew to put the tension on and it took forever to get right and didn't seem to hold as well
# 9: Ok, I was using a twist version of cargo bar that I did not like because it was a little cumbersome to put in
# 10: When I went to place this cargo bar, I could not get it tight using the ratchet at the end of the handle sweep
# 11: After placing in position I found it was not as sturdy as the rotating bar I was using, but went ahead and left the Ratcheting bar in place
# 12: Update 05/22/13: OK been using for a while now, and find it is suffice to hold a good size tool box on wheels in place at the front of the box
# 13: I wanted a strong ratchet type bar and this is exactly it
# 14: The rattling comes from the center of the bar where the ratchet is as the bar has some &#34;give and take&#34; where one slides into the other
# 15: I would imagine engineers could insert some plastic or matting inside the sleeve as cushioning to prevent the rattling, but maybe this is asking too much for a cargo bar
# 16: The ratchet on the tightening mechanism is too coarse (needs to be finer) and consequently, in order to tighten it beyond initial contact you stand the chance of bending the sheet metal in the side walls
# 17: Angling probably would fix that - some bars probably have a cross bar for this - something to think about
# 18: Also - don't get your fingers pinched in the ratcheting mechanism - I can easily see that happening
# 19: just need to learn to use it efficiently in the beginning and it works great !  recommend it for the price, does the job but takes just a bit to learn the ropes with the little ratchet release
# 20: This is  the first ratcheting cargo bar that I have had and I recomend it highly very easy to adjust and the ratchet action makes it very easy to use
# 21: When I went to tighten then ratchet down to lock, the bar would buckle a bit and jump a detent on the ratchet bar
# Sentence cluster 6:
# 1: It is no more hazardous to fingers than any of the many tools that have pinching hazards
# 2: You have to make sure you don't ratchet this thing down too hard, if you do, you will regret that last click
# 3: This thing was a steal for $25 and free shipping
# 4: Sometimes you can get more for less; so, if you want a for-real genuine bargin, don't waste money on more expensive ones that do exactly the same thing and just aren't any better, get this baby
# 5: Really, I couldn't ask for anything more, especially for the low price!  I may buy a second one
# 6: The product is cheaply made and would not stay locked in place on the desired adjustment
# 7: I received the order promptly but the ratcheting device did not function as well as I had expected
# 8: Without lubrication it still works flawlessly after a couple months of use
# 9: I can see the "risk" of pinching is there but that's never been an issue for me
# 10: Perfect for my needs -- I was a little concerned by the "pinching" reviews, but I had no problems in that regards
# 11: This is the most worthless item I believe I have ever purchased from Amazon, or anywhere else in many years
# 12: When it is tightened it just pops off the gear and will not create enough tension to hold in place
# 13: Not heavy duty, but does secure almost anything that you use on a daily basis
# 14: If you have a pick up truck,this item is a must, they are extremely durable, and I like the fact that it really stretches out there
# 15: I found I had to rotate the handle about straight out, then give it one or two more clicks
# 16: You can tell by the feel and weight that it's cheap, but it does what it's suppose to
# 17: It may function to restrain small light items but not much more
# 18: The only thing I find a little difficult is releasing it from the secured position
# 19: will not get tight enough to hold, I ratchet down as far as i can and it still will not hole very good
# 20: i tok this item to my SUV, its defict the plastic internal
# 21: I have already pinched my fingers in it several times and have only owned it for about 3 weeks
# 22: My advice is to just be careful or wear gloves while adjusting it
# 23: for sure!  I used to have one of these bars that had to be twisted to make do
# 24: For whatever reason, MOPAR did not provide a latch of any sort to hold the back seat up, out of the way, when folded
# 25: The result was an incessant flopping back and forth - totally unacceptable
# 26: I saw a strap advertised for the same purpose, but couldn't figure how - or to what - it might attach
# 27: This bar is pretty flimsy and difficult to release it will not hold anything stable that has any weight to it
# 28: My only suggestion is to modify it to keep it from rattling
# 29: I may devise a way myself to rid the rattling
# 30: ) It is easy to use and I had no problem setting it up the first time I needed it
# 31: My Ranger has one of those useless and unattractive narrow beds
# 32: Seems like it will do the job, but when I extended it in my F150, it felt real flimsy at the ratchet point
# 33: I'll have to give it a good try to see if it's sturdy enough to hold a load without sliding around, but I'm not sure
# 34: Compared to one my dad has in his Tundra, this one feels weak
# 35: You can secure this and know for sure that your cargo is not moving
# 36: It works as intended - one thing I didn't think about and am not sure if other bars do this
# 37: Its as simple if not easier than a cargo strap being no straps
# 38: I haven't had any problems with it, but it's a little difficult to get it to release some times
# 39: I wouldn't really use it to support anything heavy but to keep stuff from rolling around, it's great!
# 40: Although it does get the eventually done, it is a bit clumsy and hard to learn at first
# 41: If you are in a hurry it may slow you down or even give you a pinch (or two)
# 42: Which would in my opinon make this system useless for my needs
# 43: So EZ even a cavemen can use it!Ok, he might have a few cuts while trying!!
# Sentence cluster 7:
# 1: My husband ordered this to keep his ice chest from sliding in the back of his work truck (full-size Chevrolet)
# 2: When the ratchet is extended, the mechanism for that ends up out of arms reach when standing outside the truck
# 3: Perfect for keeping stuff from sliding around the bed of a truck during normal driving
# 4: Great for keeping the ice chest at the back of the truck
# Sentence cluster 8:
# 1: The ratchet mechanism works better than the screw or collet designs
# 2: The ratcheting lever works exactly the same as those found on cargo straps
# 3: This looks like a high quality cargo bar, but on the 2nd use, the ratcheting function broke
# 4: Quality of manufacture is excellent, it's very strong and the mechanism operates smoothly
# 5: The ratchet part works great
# 6: The ratcheting mechanism is very rough and requires some sort of ritual sacrifice in order to make it work properly
# 7: The ratchet part is very well made
# 8: The quality is there,  and the ratchet works very well
# 9: Fit great into my S10 and secures very well using the ratchet mechanism
# 10: However, it is a bit heavy and the ratchet engage/release could be easier to operate
# 11: Product is just as described, works just like a ratchet strap
# Sentence cluster 9:
# 1: Used this in my 2005 Tundra for a few months
# 2: Great for my F-150 4x4, holds well off-road in tough terrain
# 3: Use the savings for gasoline (this 65 yr
# 4: Bought this to use in the back of my Chevy Silverado
# 5: It works great on my Ford Ranger pickup
# 6: I have a Ford F150
# 7: I've been happy with it in my F350 crew cab
# 8: I've used this several times over three months on a 2013 Chevy Avalanche and it works extremely well
# 9: I used to use a bed extender on a Honda Ridgeline and it was O
# 10: This bar fits my Dodge Ram 1500 fine and seems to have plenty of strength
# 11: It works well on my '07 Tacoma
# 12: I drive a 2012 Ford F-250 Super Duty
# 13: This product works very well and stores behind the seat of my Chevy Colorado pickup
# 14: It fits fine on my 2012 Toyota Tacoma Access Cab
# Sentence cluster 10:
# 1: Much needed tool for anyone that has a truck
# 2: Doesn't get excessively tight in my truck (thus the 4 stars)
# 3: Of course once you know how to use it, does not mean others can, makes it difficult to quickly steal compare to others I've seen on friend's trucks
# 4: When not in use, it fits behind my seat in the regular cab (unfortunately always stuffed) without stealing any space
# 5: I wish I had bought one of these for my truck years ago!  No more cargo rolling around in the truck's bed!
# 6: I am just about 6 feet tall and I can't reach the ratchet standing on the side of the truck
# 7: So, every time I want to use this I need to get in the back of the truck
# 8: I bought two of these and use them to support my slide-out on my Lance truck camper when extended
# 9: I ordered it and when I got it, I felt it was cheaply made and would probably work better in a small truck rather than a full size truck like mine
# 10: I needed something more heavy duty so I returned it and ordered the Heininger 4016 HitchMate Cargo Stabilizer Bar for Full-Size Trucks
# 11: as would any extender be on any pickup but extenders don't give the ability to draw whatever you're hauling tight to the tailgate
# 12: This neat little device  works great to secure load while in the back of PU trucks
# 13: I even use it to secure a line of grocery bags on the ride home from the market
# 14: i geass its good for truck only because its metel internal
# 15: it might work in a mini truck to keep shopping bags in place but thats about it
# 16: the bar would never hold back any type of weight in a full size truck
# 17: I bought this for a trip this past summer to keep things from moving in the back of the pickup and worked great
# 18: I bought this item to keep things from rattling around in the back of my F350
# 19: If you want to secure your groceries in the family SUV, your all set
# 20: Just made the move to a pick up truck from a more car like vehicle and was having a bit of trouble getting the groceries home
# 21: This is a must have for pickup truck owners
# 22: If you are like me, I just through items in the back of my truck and hope they are still there wherever I'm going
# 23: I often travel with a slide in camper on my pickup and when at a campground, take the camper off
# 24: Even though I havent used this on my truckbed ive used it for military cargo going halfway around the world
# 25: After the cargo arrived I opened up the unit and lone behold its still right where I left it
# 26: I was buying for my jeep cherokee for when I lower the back seat for storage
# Sentence cluster 11:
# 1: Tightened down a bit and it was secure
# 2: I bought a more expensive one and returned it
# 3: the shipping time was less than expected
# 4: This was more sturdy and fit my needs better
# 5: I was expecting something more sturdy
# 6: It's a bit tricky to get used too
# 7: It was okay, but cumbersome
# 8: This solved the problem immediately, and at reasonable cost
# 9: A little on the flimsy side
# 10: A bit weak but the price is cheap
# 11: This item was horrible
# 12: I prefer those used on semi's as they can handle more weight
# 13: So it's sturdy enough to take a beating
# 14: Excellent deal!!  Would buy more if needed more
# Sentence cluster 12:
# 1: The only reason for 4 stars was it does seem a little bit cheap in the material it's made out of but for the price it's great and hopefully it doesn't rust
# 2: Instructions are too often written by professors of design engineering
# 3: Thanks Amazon! It was actually cheaper to purchase through USA & US Post & taxes than to buy the same one from a store in Canada
# 4: Waste of time and money! If the mech was closer to one side this would be a great product!
# 5: Didn't look, but probably made in China or some other third world country to specs designed by someone with a GED
# 6: It expands to 70 inches where as other products costing twice as much do not have this range and capacity
# 7: You will be impressed at the bracing strenght of one of these Keeper Cargo bars
# 8: No slipping or loosening has occurred in the 5,000 miles with this product
# 9: This is only a minor issue and it still is a great product
# 10: When extended to the width of a full-size bed, the bar's strength is greatly reduced
# 11: Even held steady my load of bags of soil from the depot Glad to have it
# 12: Missing a screw at one end now I have to go to store and find one to fit! Packing should have been better
# 13: You would be better off avoiding the purchase of this piece of junk
# 14: But with this Ratchet Cargo Bar, I can still through things, but I can now through them in the right place
# 15: Had this a long time now, catching up on Amazon reviewing, no loosening up of ratchet over time, does just what you would want it to
# Sentence cluster 13:
# 1: Ratchet mechanism took all of 30 seconds to figure out
# 2: The ratcheting mechanism does not stay securely even when the ratchet is locked
# 3: The ratchet mechanism is right in the middle of the bar instead of off center
# 4: Defective ratchet
# 5: So no slipping would occur so long as the ratchet holds
# 6: Cargo bar will not tighten tight enough to hold its self up let alone holding cargo
# 7: Ratchet unit slips when you put a load on it
# 8: My only possible complaint is the ratcheting mechanism is, well, pinchy
# 9: I have a screw type one and it is a pain
# 10: Keeps my load in place
# 11: The ratcheting mechanism slips when it is torqued enough to stay in place
# 12: Don't understand some other reviews stating problem with catching fingers in ratchet
# 13: The locking mechanism simply would not hold
# 14: Just crank down on it
# 15: That leaves me without a tailgate
# 16: Easy to use, stays locked tight
# 17: My cargo held tight
# 18: (No staying-put power)I will try the twist type system next
# Sentence cluster 14:
# 1: Works fine install took maybe 1 minute, and it stays in place
# 2: This one had one of the best reviews and so far it doing the job
# 3: I would buy this again
# 4: If I had to think of a weakness
# 5: I would absolutely purchase again
# 6: It has worked well since being put in place
# 7: I purchase this item several weeks ago and it works as advertised
# 8: I have been using it and it works very well
# 9: only had the for short time but I do like them
# 10: I would have returned it, but it took me a month  before trying it out
# 11: Perhaps I just got a lemon
# 12: I had a need for one of these one day and my brother-in-law said I could use his
# 13: that was all it took, I liked it so well I ordered two of them
# 14: His was a few years old, mine had a little better design improvement(racheting handle)
# 15: It did slip once while I was adjusting last click
# 16: It's one of those you get what you pay for
# 17: I received it fast, works as advertised
# 18: Won't work for what I had in mind for it
# 19: I might be able to find something it will work with
# 20: Just what I was looking for
# 21: It even held our new washer in place when I brought it home
# 22: It is to late to get a replacement
# 23: I didn't open the box until I needed them
# 24: I should've had one these years ago
# 25: I have been using this for almost a year now and it works great
# 26: It fits my 6
# 27: The KargoBar does exactly what I wanted
# 28: Once secured in place it stays there
# 29: I tried to install it in several locations and it would just pop off
# 30: Just received it for Christmas
# 31: I had to return one already because it broke
# 32: Lets hope this second one lives up to it's potential
# 33: Just as I expected it held in place the entire trip and it got abused
# 34: It took me a few tries to get it to open correctly
# 35: So please get familiar with it before you need it
# 36: After using it for a month or so I lost it (don't ask) and came back to buy another one
# Sentence cluster 15:
# 1: This device works well, especially on narrower truck beds
# 2: It is of high quality and held my cargo in the bed of my truck from Colorado to Southern California
# 3: The product was literally "Made in Taiwan", need I say more?  It is flimsy when extended to fit a regular size truck bed (F-150 crew)
# 4: I would not trust this cargo bar for any cargo in my truck bed
# 5: It's worth the money paid and I love it because it hold the item loaded in the rear in my truck bed
# 6: This cargo bar can hold back anything I put in the bed of my truck with no problem, it is sturdy and easy to use
# 7: The &#34;feet&#34; on this bar slides off the truck bed sides and makes it worthless
# 8: You lock it in place and hit a bump with the truck and it slips back two or three teeth and drops to the bottom of the truck bed
# 9: This expandable bar is intended to secure cargo in a pick-up truck bed
# 10: Holds things very securely in the bed of the truck
# 11: I hold my tool chess in place in the front of our truck bed
# 12: I have a full size truck and when the bar is extended to fit the truck bed it is flimzy and weak the ratchet is also a weak point
# 13: 5' F150 truck bed perfectly
# 14: It secures loads in the bed of my Toyota truck (with plastic bedliner
# 15: It provides a sturdy anchor for my cargo bed contents and will hold a mower right where you want it
# 16: Worked well in my truck bed with bedliner and camper shell
# 17: Sideways movement - yes it held my cargo up against the wall of the truck bed but, the box slid from side to side - I didn't think to angle it or anything
# 18: I received the cargo bar and installed on my truck
# 19: I bought this and the stabilizer bar to keep my cooler(s) from trashing my truck bed
# Sentence cluster 16:
# 1: My husband asked for a similar item as a gift but I wanted to see reviews so I shopped Amazon
# 2: The item was shipped and received as promised, good packaging
# 3: I highly recommend this Cargo Keeper Bar
# 4: We returned the item and paid more for a better made product he found in a store
# 5: I bought this, and it will not stay where I put it, and Im only out about a foot, keeps "popping" out! Thank God for Amazon return policy!
# 6: I would recommend them to a friend
# 7: I'm curious about how the folks who gave bad reviews are using this product
# 8: I would be on the fence to recommend this product
# 9: I would recommend this product, it does what it says, bounced to 4 star
# 10: It fit my pick-up very well and I would recommend this product
# 11: would recommend it to friends  it is  great
# 12: Great item , best one I have ever used
# 13: I just love shopping at Amazon,because they have so many great merchants
# 14: The shipping speed was terrific and the product was awesome thank you very much!!see you soon!
# 15: I am happy with my purchase for sure
# 16: Arrived as promissed and in good condition, performs as advertised and fits my need as was hoped for
# 17: Thank goodness for the Amazon return policy
# 18: I am very pleased with them, and I recommend them highly
# 19: I would highly recommend this to anybody
# 20: What can I say just a perfect design works excellent
# 21: After reading many reviews, I opted for the screw-type bar and am glad I did
# Sentence cluster 17:
# 1: Good Cargo Bar
# 2: Seems to be built very well too
# 3: The bar feels solid
# 4: Highly recommend
# 5: very nice
# 6: overall very happy with product and service
# 7: Easy to use and racheting works good
# 8: It,however,is a low cost,durable multi use product
# 9: Highly recommend this product
# 10: Pretty handy, It's not very sturdy
# 11: Easy to install, has worked well so far
# 12: In my opinion a good value as well
# 13: good  quality
# 14: a good value for the cost
# 15: Very high quality item
# 16: Stays in place very well
# 17: Great product, works real well
# 18: This is much better
# 19: This is great
# 20: This one works great every time
# 21: This thing is heavy duty and works excellent
# 22: Also the finish seems to be good quality
# 23: BUT, if you are looking for something practical, lightweight and simple this may be a good choice
# 24: Other than that, it works perfectly
# 25: Very useful and dependable
# 26: Great Product and seller
# 27: Overall great product and fast shipping
# 28: work great
# 29: This seems to work fine so far
# 30: It is made of good quality material and workmanship
# Sentence cluster 18:
# 1: Might break a weld on the inside of your bed
# 2: I can't comment on how it stands up to weather, as my bed is covered
# 3: I would absolutely recommend this product for anyone who wants to keep things in one spot in their bed or for anyone who doesn't have a tailgate
# 4: Guess where it ends up when you try to use it? In the middle of the bed
# 5: I have a bed cover on and it makes it easier to carry stuff from the store without having the stuff slide forward
# 6: At full extension needed for my bed, there's a little bend in the bar but it still holds firmly on my Rhino lined bed walls
# 7: easy to adjust and puts enough tension on the sides of the bed to keep your stuff back at the tailgate where you can get to it
# 8: I must note that I have a bed rug, and topper
# 9: This item is a bit flimsy, the ratchet isn't quite as easy to use as expected, tends to slip on the bed wall
# 10: It's easy to set up, easy to remove and adds a great measure of safety to moving gas cans as they can't flop around in the bed
# 11: This also has a secondary use--you can use it to reach to the area closest the back window to drag stuff to the tailgate area saving yourself climbing into the bed
# 12: This seems well built but my only complaint is that It doesn't seem to have the exact right adjustment for a tight fit in the bed of my pickup (almost like the size is between two clicks)
# 13: Spreads and retracts easily but has a tendency to slide on plastic bed liner
# 14: I use two of these to surround anything I place in the pickup bed to keep stuff from sliding out of the pickup
# Sentence cluster 19:
# 1: A bit of screwing around and you'll master it
# 2: When you hold it up to crank it tight, the bar is awkward to hold because it is off balance
# 3: Careful of those fingers as they can get smashed!
# 4: After 200 miles of driving, bumpy roads, hills, ext
# 5: It's great for short trips where you don't want something sliding around too much
# 6: With just a bit of experimenting, I got the hang of it - installing and uninstalling - quickly
# 7: Keeps items from moving around and holds them steady
# 8: The bar rattles some while traveling at higher speeds
# 9: Stuff sliding all over the place and getting difficult to get out
# 10: Has held 125# generator in place from Texas to DC and back
# 11: Could only achieve tension to hold bar in place in certain spots
# 12: Back in the box and the return process started within 15 min of receiving it
# 13: Keeps it from sliding around and breaking my fishing rods :-)
# 14: Lots of bumps and jumps and still works like a champ
# Sentence cluster 20:
# 1: Holds things inplace, and very easy to use
# 2: The ratcheting system appears solid, is easy to operate, and operates smoothly
# 3: This bar is easy to adjust and the ratcheting feature lets you tighten it down perfectly
# 4: Easy to snap in and take out
# 5: It is easy to use and stays in place without damage
# 6: It is really easy to adjust and move around
# 7: Easy to place in the truck and easy to remove
# 8: It was very easy to install (old lady here) and it works very nicely
# 9: A good buy for the moned, strong, adjusts easy aand seem of good quality
# 10: The bar is easy to adjust and with the rubber feet stays firmly in place
# 11: Its lighter and quicker and easier to install and move

# %%
from sklearn.cluster import SpectralClustering
from sklearn import metrics

# Spectral Clustering
sc = SpectralClustering(20, affinity='nearest_neighbors', n_init=1000)
sc.fit(embeddings)
print('spectral clustering')
print(sc.labels_)
# Out:
# spectral clustering
# [18  4  2 14 14  4 13  9  4  4 15 11 11  0 10 17  4  0  4  4  4  3  9  4  1
#  11  4 17  0  4  4  0  0  7 11  4 13 16  1 13  6 19 12 17  4 11  7  5  5 12
#   4 13  4  8  2  3  9 18  0  3  5 17 18 12  3 17  1  0  3  0  2 11  2  9 14
#   2 19 10  4 19  2 14  4  2  5  4  5  4  4 18 13  3  2 10  7 12 16  8  4 17
#   7 10 10  4  7 16 13 14 15 13  9  6  4  4  4  4  0 10 10 15  8 18 13  8  6
#  15  0 14  3  3 13  4  0  9 15  0 14 14  5  4 19  4  0  4  4  4  0  4 16 18
#   4  3  4 13  4  3 10  4 17 10  4  1  0  2  4 18 13  4  0  6  3  4  4 18  3
#   8 16  1  3  3  8  7 19 19  3  3  0  4 12 12 12  5 16 17  4 11 14  4 17  6
#  16 12  1 14 14  4 19 13  4 19 14  2  0  4 16 13  4  0  4 18  2  0 18  3  4
#  12 19  4 19  4  7  4 13  5  5 10 13  4 18 11  9  4 16  4  4  3  6  7  3  4
#  15 13 11  9  4 19  0  9 12 15  7  8  4  4  6 16 16 18  1  4  9  6 18 12  3
#   8 13  4  2 17  4  1  4 15  4  7 11 14  4  4 13  4  4 10 19  4  0  0  4 18
#   4 11  0  7 17  4 19  8  3 15 18 18  8  1  2  4  4  4 18  4  2  0  4 14 14
#   4 15  4  9  7  2  4 11 16  0 18  6  0 18  4  8  2 14  4 12 19 19  7  4  0
#   2 13 18  4  9 13  3 11  0 14 13 12  8  4 11  9 11 14  4  6 18  5 13  4  4
#   4 17  2 13 11  4  1]

# %%
labels = sc.labels_.flatten()
print(labels.shape)
labels = list(labels)
for i in set(sc.labels_):
    print(str(i)+': '+str(labels.count(i)))
# Out:
# (382,)
# 0: 29
# 1: 10
# 2: 18
# 3: 22
# 4: 94
# 5: 10
# 6: 10
# 7: 13
# 8: 12
# 9: 13
# 10: 11
# 11: 16
# 12: 13
# 13: 23
# 14: 18
# 15: 10
# 16: 12
# 17: 12
# 18: 21
# 19: 15

# %%
print(sc.labels_[:5])
# Out:
# [18  4  2 14 14]

# %%
for i in range(40):
    print('Cluster '+str(i)+':')
    cnt = 1
    for k, l in enumerate(sentences):
        if sc.labels_[k] == i:
            print(str(cnt)+': '+l)
            cnt += 1
    print()
# Out:
# Cluster 0:
# 1: It is no more hazardous to fingers than any of the many tools that have pinching hazards
# 2: You have to make sure you don't ratchet this thing down too hard, if you do, you will regret that last click
# 3: Just a wee bit tricky to learn to operate at first, blame instructions on one word, instead of saying "rotate" should say "pull over" for the lever, engage last black notch (so easy to miss), then adjust length to short or long quickly
# 4: Of course once you know how to use it, does not mean others can, makes it difficult to quickly steal compare to others I've seen on friend's trucks
# 5: When not in use, it fits behind my seat in the regular cab (unfortunately always stuffed) without stealing any space
# 6: The product is cheaply made and would not stay locked in place on the desired adjustment
# 7: I received the order promptly but the ratcheting device did not function as well as I had expected
# 8: I just received 2 ratcheting cargo bars and I am just as quickly returning them back to Amazon
# 9: When it is tightened it just pops off the gear and will not create enough tension to hold in place
# 10: Not heavy duty, but does secure almost anything that you use on a daily basis
# 11: Ok, I was using a twist version of cargo bar that I did not like because it was a little cumbersome to put in
# 12: When I went to place this cargo bar, I could not get it tight using the ratchet at the end of the handle sweep
# 13: So no slipping would occur so long as the ratchet holds
# 14: No slipping or loosening has occurred in the 5,000 miles with this product
# 15: as would any extender be on any pickup but extenders don't give the ability to draw whatever you're hauling tight to the tailgate
# 16: will not get tight enough to hold, I ratchet down as far as i can and it still will not hole very good
# 17: Cargo bar will not tighten tight enough to hold its self up let alone holding cargo
# 18: For whatever reason, MOPAR did not provide a latch of any sort to hold the back seat up, out of the way, when folded
# 19: This bar is pretty flimsy and difficult to release it will not hold anything stable that has any weight to it
# 20: the bar would never hold back any type of weight in a full size truck
# 21: I quests your fingers could get caught if you were not paying attention, but you could get hit by a bus for the same reason
# 22: Seems like it will do the job, but when I extended it in my F150, it felt real flimsy at the ratchet point
# 23: I'll have to give it a good try to see if it's sturdy enough to hold a load without sliding around, but I'm not sure
# 24: You can secure this and know for sure that your cargo is not moving
# 25: Had this a long time now, catching up on Amazon reviewing, no loosening up of ratchet over time, does just what you would want it to
# 26: just need to learn to use it efficiently in the beginning and it works great !  recommend it for the price, does the job but takes just a bit to learn the ropes with the little ratchet release
# 27: Its as simple if not easier than a cargo strap being no straps
# 28: This is  the first ratcheting cargo bar that I have had and I recomend it highly very easy to adjust and the ratchet action makes it very easy to use
# 29: Although it does get the eventually done, it is a bit clumsy and hard to learn at first
#
# Cluster 1:
# 1: Bob
# 2: driver's curse)
# 3: Enjoy
# 4: K
# 5: ,
# 6: One is broken
# 7: LOL
# 8: keep looking
# 9: A+++++++++++++
# 10: Thanks
#
# Cluster 2:
# 1: I have a 2007 Tacoma that I broke the tailgate on, so as a temporary repair I got a tailgate net and one of these bars to help prevent bed flex and also for when there was stuff in the bed
# 2: This was an early Fathers Day gift for my husband, and he couldn't be happier! Easy to use, love the ratchet instead of a twist and lock,held the load in the truck without shifting when we went camping (literally 40 miles of bad road), good pads on ends so truck bed is protected
# 3: The product was literally "Made in Taiwan", need I say more?  It is flimsy when extended to fit a regular size truck bed (F-150 crew)
# 4: I would not trust this cargo bar for any cargo in my truck bed
# 5: It's worth the money paid and I love it because it hold the item loaded in the rear in my truck bed
# 6: This cargo bar can hold back anything I put in the bed of my truck with no problem, it is sturdy and easy to use
# 7: The &#34;feet&#34; on this bar slides off the truck bed sides and makes it worthless
# 8: I have a bed cover on and it makes it easier to carry stuff from the store without having the stuff slide forward
# 9: This also has a secondary use--you can use it to reach to the area closest the back window to drag stuff to the tailgate area saving yourself climbing into the bed
# 10: So far, no "pinches", either; perhaps I was forewarned by the misadventures of others, but I'm nevertheless cautious!  It grips tightly, and doesn't slip; it packs up to a small, manageable size; what's not to like?  BTW, I'm using this to hold up the folded rear seat of our '13 2-Dr Jeep Wrangler
# 11: I have a full size truck and when the bar is extended to fit the truck bed it is flimzy and weak the ratchet is also a weak point
# 12: This seems well built but my only complaint is that It doesn't seem to have the exact right adjustment for a tight fit in the bed of my pickup (almost like the size is between two clicks)
# 13: Been a great cargo bar, I use it for holding plastic bins in place in the bed of my truck and so far it has worked great and has never budged unless I have removed it intentionally
# 14: I use two of these to surround anything I place in the pickup bed to keep stuff from sliding out of the pickup
# 15: Sideways movement - yes it held my cargo up against the wall of the truck bed but, the box slid from side to side - I didn't think to angle it or anything
# 16: I bought this cargo bar in a hurry to keep our coolers and gas cans in place during our 800 mile death valley off road adventure
# 17: It's a little bit on the flimsy side, but I does section your truck bed out to help keep your groceries from not rolling around back there
# 18: I bought this and the stabilizer bar to keep my cooler(s) from trashing my truck bed
#
# Cluster 3:
# 1: This one had one of the best reviews and so far it doing the job
# 2: The item was shipped and received as promised, good packaging
# 3: We returned the item and paid more for a better made product he found in a store
# 4: I bought a more expensive one and returned it
# 5: It has worked well since being put in place
# 6: I have been using it and it works very well
# 7: that was all it took, I liked it so well I ordered two of them
# 8: His was a few years old, mine had a little better design improvement(racheting handle)
# 9: This was more sturdy and fit my needs better
# 10: I was expecting something more sturdy
# 11: It fit my pick-up very well and I would recommend this product
# 12: I received it fast, works as advertised
# 13: would recommend it to friends  it is  great
# 14: Great item , best one I have ever used
# 15: I just love shopping at Amazon,because they have so many great merchants
# 16: The shipping speed was terrific and the product was awesome thank you very much!!see you soon!
# 17: I should've had one these years ago
# 18: I have been using this for almost a year now and it works great
# 19: I am happy with my purchase for sure
# 20: Arrived as promissed and in good condition, performs as advertised and fits my need as was hoped for
# 21: I am very pleased with them, and I recommend them highly
# 22: What can I say just a perfect design works excellent
#
# Cluster 4:
# 1: Fits in any location and allows you to store equipment securely
# 2: Tightened down a bit and it was secure
# 3: Doesn't get excessively tight in my truck (thus the 4 stars)
# 4: Good construction, use it as a cargo separator under my tonneau cover
# 5: It is ok for what it's intended to do, which is be a lightweight cargo divider
# 6: Might break a weld on the inside of your bed
# 7: This thing was a steal for $25 and free shipping
# 8: My husband asked for a similar item as a gift but I wanted to see reviews so I shopped Amazon
# 9: It is of high quality and held my cargo in the bed of my truck from Colorado to Southern California
# 10: It's useless now
# 11: Instructions are too often written by professors of design engineering
# 12: A bit of screwing around and you'll master it
# 13: I'm not really well off so I'm careful with my money
# 14: The bar feels solid
# 15: I can't comment on how it stands up to weather, as my bed is covered
# 16: One high, one low
# 17: I don't know how good this product will be on holding back heavy items, but it works well on garden flowers they all stead in place with this bar
# 18: I would absolutely recommend this product for anyone who wants to keep things in one spot in their bed or for anyone who doesn't have a tailgate
# 19: I bought this, and it will not stay where I put it, and Im only out about a foot, keeps "popping" out! Thank God for Amazon return policy!
# 20: Guess where it ends up when you try to use it? In the middle of the bed
# 21: I am just about 6 feet tall and I can't reach the ratchet standing on the side of the truck
# 22: I'm curious about how the folks who gave bad reviews are using this product
# 23: No regrets from me on this purchase
# 24: Careful of those fingers as they can get smashed!
# 25: Defective ratchet
# 26: Will not hold in place
# 27: Perhaps I just got a lemon
# 28: You will be impressed at the bracing strenght of one of these Keeper Cargo bars
# 29: After 200 miles of driving, bumpy roads, hills, ext
# 30: I must note that I have a bed rug, and topper
# 31: I would be on the fence to recommend this product
# 32: It will work, but not as tight as the turn stile
# 33: Update 05/22/13: OK been using for a while now, and find it is suffice to hold a good size tool box on wheels in place at the front of the box
# 34: I would recommend this product, it does what it says, bounced to 4 star
# 35: I needed something more heavy duty so I returned it and ordered the Heininger 4016 HitchMate Cargo Stabilizer Bar for Full-Size Trucks
# 36: Pretty handy, It's not very sturdy
# 37: It's great for short trips where you don't want something sliding around too much
# 38: It may function to restrain small light items but not much more
# 39: I used to use a bed extender on a Honda Ridgeline and it was O
# 40: This neat little device  works great to secure load while in the back of PU trucks
# 41: It's a bit tricky to get used too
# 42: In my opinion a good value as well
# 43: i tok this item to my SUV, its defict the plastic internal
# 44: Ratchet unit slips when you put a load on it
# 45: It even held our new washer in place when I brought it home
# 46: My advice is to just be careful or wear gloves while adjusting it
# 47: Open your box ASAP
# 48: It was okay, but cumbersome
# 49: The result was an incessant flopping back and forth - totally unacceptable
# 50: This, to quote a phrase, is "more better"!
# 51: This product is trash
# 52: Keeps items from moving around and holds them steady
# 53: I have a screw type one and it is a pain
# 54: Keeps my load in place
# 55: Performs exactly as expected
# 56: This is only a minor issue and it still is a great product
# 57: A little on the flimsy side
# 58: If your moving anything heavy don't count on this bar
# 59: If you want to secure your groceries in the family SUV, your all set
# 60: It fits my 6
# 61: Don't understand some other reviews stating problem with catching fingers in ratchet
# 62: I've had several different types of cargo retaining mechanisms, but this one works
# 63: Once secured in place it stays there
# 64: Stuff sliding all over the place and getting difficult to get out
# 65: Ends were open
# 66: If you are looking for a heavy duty piece of equipment
# 67: BUT, if you are looking for something practical, lightweight and simple this may be a good choice
# 68: This item was horrible
# 69: The device is not worth it
# 70: Thank goodness for the Amazon return policy
# 71: My Ranger has one of those useless and unattractive narrow beds
# 72: These cargo bars fit it perfectly - no complaints with the quality or operation after a winter of holding cargo
# 73: Just received it for Christmas
# 74: Compared to one my dad has in his Tundra, this one feels weak
# 75: The bar is easy to adjust and with the rubber feet stays firmly in place
# 76: It provides a sturdy anchor for my cargo bed contents and will hold a mower right where you want it
# 77: Spreads and retracts easily but has a tendency to slide on plastic bed liner
# 78: Has held 125# generator in place from Texas to DC and back
# 79: Just crank down on it
# 80: That leaves me without a tailgate
# 81: Could only achieve tension to hold bar in place in certain spots
# 82: Lets hope this second one lives up to it's potential
# 83: Keeps it from sliding around and breaking my fishing rods :-)
# 84: Angling probably would fix that - some bars probably have a cross bar for this - something to think about
# 85: My cargo held tight
# 86: Lots of bumps and jumps and still works like a champ
# 87: I`ve owned cargo bars in the past but they were threaded and difficult to extend constently
# 88: I was disappointed in the bar diameter and overall durability
# 89: So it's sturdy enough to take a beating
# 90: After reading many reviews, I opted for the screw-type bar and am glad I did
# 91: (No staying-put power)I will try the twist type system next
# 92: Keeper 05059 Ratcheting Cargo BarSorry  Will S
# 93: New Hampshire
# 94: Excellent deal!!  Would buy more if needed more
#
# Cluster 5:
# 1: if I was the designer of this tool, I would have tried to figure out a way to put the ratchet in the middle of the bar
# 2: When you hold it up to crank it tight, the bar is awkward to hold because it is off balance
# 3: This bar is easy to adjust and the ratcheting feature lets you tighten it down perfectly
# 4: When the ratchet is extended, the mechanism for that ends up out of arms reach when standing outside the truck
# 5: The ratchet mechanism is right in the middle of the bar instead of off center
# 6: After placing in position I found it was not as sturdy as the rotating bar I was using, but went ahead and left the Ratcheting bar in place
# 7: I wanted a strong ratchet type bar and this is exactly it
# 8: The bar rattles some while traveling at higher speeds
# 9: The rattling comes from the center of the bar where the ratchet is as the bar has some &#34;give and take&#34; where one slides into the other
# 10: When I went to tighten then ratchet down to lock, the bar would buckle a bit and jump a detent on the ratchet bar
#
# Cluster 6:
# 1: Holds things inplace, and very easy to use
# 2: Easy to use and racheting works good
# 3: Easy to snap in and take out
# 4: Easy to install, has worked well so far
# 5: It is easy to use and stays in place without damage
# 6: It is really easy to adjust and move around
# 7: Easy to place in the truck and easy to remove
# 8: It was very easy to install (old lady here) and it works very nicely
# 9: Easy to use, stays locked tight
# 10: Its lighter and quicker and easier to install and move
#
# Cluster 7:
# 1: Cannot believe that there are actually some poor reviews
# 2: If I had to think of a weakness
# 3: only had the for short time but I do like them
# 4: I can see the "risk" of pinching is there but that's never been an issue for me
# 5: Perfect for my needs -- I was a little concerned by the "pinching" reviews, but I had no problems in that regards
# 6: I have had no problems with it
# 7: It has not failed me yet
# 8: Never had a problem with it slipping or not unlocking or anything
# 9: ) It is easy to use and I had no problem setting it up the first time I needed it
# 10: It was unable to stay in the locked position even with no stress being placed on it
# 11: Have had no problems at all
# 12: It works as intended - one thing I didn't think about and am not sure if other bars do this
# 13: I haven't had any problems with it, but it's a little difficult to get it to release some times
#
# Cluster 8:
# 1: Highly recommend
# 2: overall very happy with product and service
# 3: It,however,is a low cost,durable multi use product
# 4: Highly recommend this product
# 5: good  quality
# 6: Very high quality item
# 7: Also the finish seems to be good quality
# 8: A good buy for the moned, strong, adjusts easy aand seem of good quality
# 9: Very useful and dependable
# 10: Great Product and seller
# 11: Overall great product and fast shipping
# 12: It is made of good quality material and workmanship
#
# Cluster 9:
# 1: Good Cargo Bar
# 2: The cargo bar is great
# 3: I highly recommend this Cargo Keeper Bar
# 4: I was looking for a sturdy, quality made cargo restraint bar and this is not it
# 5: Nice cargo bar for the price
# 6: I thought this cargo bar would be easier to place in a lot let time
# 7: I would recommend trying a different cargo bar
# 8: I do not recommend this cargo bar
# 9: If you want a quality, heavy duty cargo bar at a good price, this is it
# 10: Someone recommended a cargo bar and I bought this one
# 11: I'm fairly pleased with this cargo bar
# 12: I would recommend you keep looking for a sturdier cargo bar
# 13: This cargo bar is well made and capable of holding almost any size/weight load in place
#
# Cluster 10:
# 1: The ratchet increments are wide enough that you may need to test where along the the bed wall the bar can be most effectively tightened
# 2: The only con I have is the rubber pads on the ends are too hard and you just can't that last click to get it tight enough to stay in place
# 3: I like these bars they are easy to use and stay in place, with the rubber encased feet the hold wherever you install them, they will extend to full width of bed or retract to between wheel wells
# 4: At full extension needed for my bed, there's a little bend in the bar but it still holds firmly on my Rhino lined bed walls
# 5: I suspect a slippery plastic bed wall would require more pressure to hold firmly and thus not work as well thus the comments of needing a finer ratchet to make that little bit more extension
# 6: easy to adjust and puts enough tension on the sides of the bed to keep your stuff back at the tailgate where you can get to it
# 7: Used to have one of the ones that used threaded rod to unscrew to put the tension on and it took forever to get right and didn't seem to hold as well
# 8: This item is a bit flimsy, the ratchet isn't quite as easy to use as expected, tends to slip on the bed wall
# 9: It's easy to set up, easy to remove and adds a great measure of safety to moving gas cans as they can't flop around in the bed
# 10: I would imagine engineers could insert some plastic or matting inside the sleeve as cushioning to prevent the rattling, but maybe this is asking too much for a cargo bar
# 11: The ratchet on the tightening mechanism is too coarse (needs to be finer) and consequently, in order to tighten it beyond initial contact you stand the chance of bending the sheet metal in the side walls
#
# Cluster 11:
# 1: The ratchet mechanism works better than the screw or collet designs
# 2: The ratcheting lever works exactly the same as those found on cargo straps
# 3: This looks like a high quality cargo bar, but on the 2nd use, the ratcheting function broke
# 4: Quality of manufacture is excellent, it's very strong and the mechanism operates smoothly
# 5: The ratcheting system appears solid, is easy to operate, and operates smoothly
# 6: The ratcheting mechanism does not stay securely even when the ratchet is locked
# 7: My only possible complaint is the ratcheting mechanism is, well, pinchy
# 8: The ratcheting mechanism slips when it is torqued enough to stay in place
# 9: The ratcheting mechanism is very rough and requires some sort of ritual sacrifice in order to make it work properly
# 10: The locking mechanism simply would not hold
# 11: The ratchet part is very well made
# 12: Also - don't get your fingers pinched in the ratcheting mechanism - I can easily see that happening
# 13: The quality is there,  and the ratchet works very well
# 14: Fit great into my S10 and secures very well using the ratchet mechanism
# 15: However, it is a bit heavy and the ratchet engage/release could be easier to operate
# 16: Product is just as described, works just like a ratchet strap
#
# Cluster 12:
# 1: I would buy this again
# 2: So petty, I know
# 3: I would absolutely purchase again
# 4: I would recommend them to a friend
# 5: Won't work for what I had in mind for it
# 6: I might be able to find something it will work with
# 7: Just what I was looking for
# 8: I ordered two
# 9: I would recommend
# 10: The KargoBar does exactly what I wanted
# 11: now I need a topper!
# 12: I would highly recommend this to anybody
# 13: So please get familiar with it before you need it
#
# Cluster 13:
# 1: The only reason for 4 stars was it does seem a little bit cheap in the material it's made out of but for the price it's great and hopefully it doesn't rust
# 2: Sometimes you can get more for less; so, if you want a for-real genuine bargin, don't waste money on more expensive ones that do exactly the same thing and just aren't any better, get this baby
# 3: Thanks Amazon! It was actually cheaper to purchase through USA & US Post & taxes than to buy the same one from a store in Canada
# 4: Really, I couldn't ask for anything more, especially for the low price!  I may buy a second one
# 5: Waste of time and money! If the mech was closer to one side this would be a great product!
# 6: This is the most worthless item I believe I have ever purchased from Amazon, or anywhere else in many years
# 7: Didn't look, but probably made in China or some other third world country to specs designed by someone with a GED
# 8: It expands to 70 inches where as other products costing twice as much do not have this range and capacity
# 9: If you have a pick up truck,this item is a must, they are extremely durable, and I like the fact that it really stretches out there
# 10: You can tell by the feel and weight that it's cheap, but it does what it's suppose to
# 11: The only thing I find a little difficult is releasing it from the secured position
# 12: for sure!  I used to have one of these bars that had to be twisted to make do
# 13: I saw a strap advertised for the same purpose, but couldn't figure how - or to what - it might attach
# 14: My only suggestion is to modify it to keep it from rattling
# 15: I may devise a way myself to rid the rattling
# 16: When extended to the width of a full-size bed, the bar's strength is greatly reduced
# 17: Missing a screw at one end now I have to go to store and find one to fit! Packing should have been better
# 18: You would be better off avoiding the purchase of this piece of junk
# 19: I wouldn't really use it to support anything heavy but to keep stuff from rolling around, it's great!
# 20: I prefer those used on semi's as they can handle more weight
# 21: If you are in a hurry it may slow you down or even give you a pinch (or two)
# 22: Which would in my opinon make this system useless for my needs
# 23: So EZ even a cavemen can use it!Ok, he might have a few cuts while trying!!
#
# Cluster 14:
# 1: Ratchet mechanism took all of 30 seconds to figure out
# 2: Works fine install took maybe 1 minute, and it stays in place
# 3: I purchase this item several weeks ago and it works as advertised
# 4: Without lubrication it still works flawlessly after a couple months of use
# 5: I would have returned it, but it took me a month  before trying it out
# 6: I had a need for one of these one day and my brother-in-law said I could use his
# 7: I found I had to rotate the handle about straight out, then give it one or two more clicks
# 8: It did slip once while I was adjusting last click
# 9: I have already pinched my fingers in it several times and have only owned it for about 3 weeks
# 10: It is to late to get a replacement
# 11: I didn't open the box until I needed them
# 12: With just a bit of experimenting, I got the hang of it - installing and uninstalling - quickly
# 13: I tried to install it in several locations and it would just pop off
# 14: Back in the box and the return process started within 15 min of receiving it
# 15: I had to return one already because it broke
# 16: Just as I expected it held in place the entire trip and it got abused
# 17: It took me a few tries to get it to open correctly
# 18: After using it for a month or so I lost it (don't ask) and came back to buy another one
#
# Cluster 15:
# 1: This device works well, especially on narrower truck beds
# 2: You lock it in place and hit a bump with the truck and it slips back two or three teeth and drops to the bottom of the truck bed
# 3: This expandable bar is intended to secure cargo in a pick-up truck bed
# 4: Holds things very securely in the bed of the truck
# 5: I hold my tool chess in place in the front of our truck bed
# 6: 5' F150 truck bed perfectly
# 7: It secures loads in the bed of my Toyota truck (with plastic bedliner
# 8: Perfect for keeping stuff from sliding around the bed of a truck during normal driving
# 9: Worked well in my truck bed with bedliner and camper shell
# 10: Great for keeping the ice chest at the back of the truck
#
# Cluster 16:
# 1: Use the savings for gasoline (this 65 yr
# 2: the shipping time was less than expected
# 3: Super value
# 4: It's one of those you get what you pay for
# 5: a good value for the cost
# 6: Would buy again!
# 7: The price is right too
# 8: This solved the problem immediately, and at reasonable cost
# 9: A bit weak but the price is cheap
# 10: I'd buy it again
# 11: Outstanding price
# 12: definitely worth the price
#
# Cluster 17:
# 1: Used this in my 2005 Tundra for a few months
# 2: Great for my F-150 4x4, holds well off-road in tough terrain
# 3: Bought this to use in the back of my Chevy Silverado
# 4: It works great on my Ford Ranger pickup
# 5: I have a Ford F150
# 6: I've been happy with it in my F350 crew cab
# 7: I've used this several times over three months on a 2013 Chevy Avalanche and it works extremely well
# 8: This bar fits my Dodge Ram 1500 fine and seems to have plenty of strength
# 9: It works well on my '07 Tacoma
# 10: I drive a 2012 Ford F-250 Super Duty
# 11: This product works very well and stores behind the seat of my Chevy Colorado pickup
# 12: It fits fine on my 2012 Toyota Tacoma Access Cab
#
# Cluster 18:
# 1: Much needed tool for anyone that has a truck
# 2: My husband ordered this to keep his ice chest from sliding in the back of his work truck (full-size Chevrolet)
# 3: I wish I had bought one of these for my truck years ago!  No more cargo rolling around in the truck's bed!
# 4: So, every time I want to use this I need to get in the back of the truck
# 5: I bought two of these and use them to support my slide-out on my Lance truck camper when extended
# 6: I ordered it and when I got it, I felt it was cheaply made and would probably work better in a small truck rather than a full size truck like mine
# 7: I even use it to secure a line of grocery bags on the ride home from the market
# 8: i geass its good for truck only because its metel internal
# 9: it might work in a mini truck to keep shopping bags in place but thats about it
# 10: I bought this for a trip this past summer to keep things from moving in the back of the pickup and worked great
# 11: I bought this item to keep things from rattling around in the back of my F350
# 12: Just made the move to a pick up truck from a more car like vehicle and was having a bit of trouble getting the groceries home
# 13: Even held steady my load of bags of soil from the depot Glad to have it
# 14: This is a must have for pickup truck owners
# 15: If you are like me, I just through items in the back of my truck and hope they are still there wherever I'm going
# 16: But with this Ratchet Cargo Bar, I can still through things, but I can now through them in the right place
# 17: I often travel with a slide in camper on my pickup and when at a campground, take the camper off
# 18: Even though I havent used this on my truckbed ive used it for military cargo going halfway around the world
# 19: After the cargo arrived I opened up the unit and lone behold its still right where I left it
# 20: I received the cargo bar and installed on my truck
# 21: I was buying for my jeep cherokee for when I lower the back seat for storage
#
# Cluster 19:
# 1: Seems to be built very well too
# 2: The ratchet part works great
# 3: very nice
# 4: it is still in place and working
# 5: Stays in place very well
# 6: Great product, works real well
# 7: The one works ok
# 8: This is much better
# 9: This is great
# 10: This one works great every time
# 11: This thing is heavy duty and works excellent
# 12: Other than that, it works perfectly
# 13: They work just as described
# 14: work great
# 15: This seems to work fine so far
#
# Cluster 20:
#
# Cluster 21:
#
# Cluster 22:
#
# Cluster 23:
#
# Cluster 24:
#
# Cluster 25:
#
# Cluster 26:
#
# Cluster 27:
#
# Cluster 28:
#
# Cluster 29:
#
# Cluster 30:
#
# Cluster 31:
#
# Cluster 32:
#
# Cluster 33:
#
# Cluster 34:
#
# Cluster 35:
#
# Cluster 36:
#
# Cluster 37:
#
# Cluster 38:
#
# Cluster 39:

# %%
# Load reviews
reviews = []
with open('text_0_AutomotiveProd7.txt') as f:
    i = 1
    rev_num = -1
    for line in f:
        if i == 1:
            rev_num += 1
            l = line.strip()
            reviews.append(l)
            i *= -1
        else:
            i *= -1
print(len(reviews))
# Out:
# 101

# %%
rev_cluster = []
for i, rev in enumerate(reviews):
    rev_specific_cluster = []
    for j, sent in enumerate(sentences):
        if sent in rev:
            rev_specific_cluster.append(sc.labels_[j])
    rev_cluster.append([i, list(set(rev_specific_cluster))])

# %%
print(rev_cluster[1])
# Out:
# [1, [1, 2, 4, 13, 14]]

# %% [markdown]
# ### OfficeProd13

# %%
# Load sentences
sentences = []
indi_sent_rev = []
with open('text_0_OfficeProd13.txt') as f:
    i = 1
    rev_num = -1
    for line in f:
        if i == 1:
            rev_num += 1
            l = line.strip()
            indi_sent = l.split('.')
            indi_sent = [a.strip() for a in indi_sent]
            indi_sent = list(filter(None, indi_sent))
            for k in range(len(indi_sent)):
                indi_sent_rev.append(rev_num)
            sentences.extend(indi_sent)
            i *= -1
        else:
            i *= -1
print(len(sentences))
# Out:
# 401

# %%
embeddings = model.encode(sentences, bsize=128, tokenize=False, verbose=True)
print('nb sentences encoded : {0}'.format(len(embeddings)))
# Out:
# Nb words kept : 5944/6476 (91.79 %)
# Speed : 16.34 sentences/s (cpu mode, bsize=128)
# nb sentences encoded : 401

# %%
from sklearn.cluster import SpectralClustering
from sklearn import metrics

# Spectral Clustering
sc = SpectralClustering(20, affinity='nearest_neighbors', n_init=1000)
sc.fit(embeddings)
# Out:
# SpectralClustering(affinity='nearest_neighbors', assign_labels='kmeans',
#           coef0=1, degree=3, eigen_solver=None, eigen_tol=0.0, gamma=1.0,
#           kernel_params=None, n_clusters=20, n_init=1000, n_jobs=1,
#           n_neighbors=10, random_state=None)

# %%
labels = sc.labels_.flatten()
print(labels.shape)
labels = list(labels)
for i in set(sc.labels_):
    print(str(i)+': '+str(labels.count(i)))
# Out:
# (401,)
# 0: 16
# 1: 111
# 2: 18
# 3: 11
# 4: 10
# 5: 9
# 6: 8
# 7: 8
# 8: 16
# 9: 9
# 10: 14
# 11: 14
# 12: 24
# 13: 16
# 14: 18
# 15: 15
# 16: 36
# 17: 18
# 18: 17
# 19: 13

# %%
for i in range(40):
    print('Cluster '+str(i)+':')
    cnt = 1
    for k, l in enumerate(sentences):
        if sc.labels_[k] == i:
            print(str(cnt)+': '+l)
            cnt += 1
    print()
# Out:
# Cluster 0:
# 1: spent a whole 10 bucks :) and I just threw these bastards arround the house on every drawer on every corner, everywhere
# 2: This box of 60 I bought, arrived and I counted an exact 44 pens in it, not sure where the remaining 16 went to
# 3: I have used at least 20 of them so far & have yet to come across one that doesn't work well
# 4: This package, as an 'add-on' item, cost under 10 cents per pen so I ordered two and took them in
# 5: Your basic pen in a high enough quantity that you don't mind if a few dozen go missing
# 6: I have to buy a bunch of these for the office since they keep disappearing
# 7: I tend to lose a lot of pens before they run out of ink, so can't speak to how long they'll last, but I'm sure i'll be buying these again once i lose all 60 again
# 8: I have found that even I have trouble loosing these things if I buy them a dozen at a time
# 9: 60 pens in one box for a low price! I haven't used all the pens so far, but what I've used and given away worked without problems
# 10: At the time of this review this box of 60 pens is only 54 cents higher in cost than buying a 10 pack on Amazon
# 11: So for 54 cents you get 50 more pens, that's an obviously fantastic deal
# 12: Except that they work, even after sitting long periods of time!  I haven't had a single issue with any of these pens
# 13: Now I have 60 to last me quite a long time
# 14: I decided to buy this 60 pack when I saw that the pens had a new design
# 15: The front label says &#34;Writes first time, every time!&#34; I tried all 10 pens and only 2 would write
# 16: The item was entirely wrapped in tape, precluding the possibility of being unintentionally opened, and promptly arrived in less than three days of ordering
#
# Cluster 1:
# 1: Great deal on a lot of ink pens
# 2: Hands down, best product for this kind of money, I was tired of never finding pens, so I bought three boxes of these
# 3: I'm a happy man
# 4: These pens are durable, always ready, light, beautiful, at this price it's crazy!!
# 5: I am bummed I have a lot of them
# 6: 60 pens should last a college student such as myself a long time
# 7: 69, making each pen cost about 8 cents, which is a satisfying price
# 8: We play a lot of group games, which means we need a lot of pens, and that a lot of those pens walk off
# 9: For these purposes you cannot beat your basic BIC pen
# 10: Great value!  Price is hard to beat
# 11: Pen works well
# 12: 36 pens with 2-day Amazon Prime delivery? Yes please! Seriously though, these are just what you expect: good old Bic ball point pens
# 13: Prices seem to vary on this product, so I'd suggest browsing through the various sizes/colors to find the current best deal
# 14: Bic are my favorite pens, as they write despite the weather or time stored
# 15: I have taken these overseas for storage and use in our bookstore and they always work
# 16: Bic never disappoints!! As I've stated before I am a college student and I don't have time to be running out of things so bulk is better for me and Bic has never disappointed me
# 17: Anyway Amazon was kind enough to refund me the $4
# 18: Product wise, all 44 pens tested working, able to write smoothly
# 19: The picture on the box was not what I received
# 20: Purchased in bulk
# 21: Arrived promptly and as described
# 22: 60 for $5
# 23: Now, I'm not as concerned with whether, or not, I get the pens back because replacing them doesn't cost me an arm and a leg
# 24: These should last my four grandchildren a couple years
# 25: I have several friends who are servers at my favorite restaurant
# 26: These are decent quality and an awesome price
# 27: Used to purchase pens from costco and sams club but they wouldn't write on paper when written on top of glass
# 28: I think they have legs and just run away after awhile
# 29: Good quality pen at the right price!
# 30: My employees like them so I think I will continue to buy them
# 31: I find the medium size is bold enough to see without being in optimum light
# 32: The cost of each pen is great, I don't mind lending these to someone that needs one
# 33: I carry a very large canvas pouch with me stuffed with stuff
# 34: "  Ha
# 35: I have the little twerps! And I don't even have to be mean about it like I do with the endless bathroom and drink requests
# 36: If the student forgets to return the pen
# 37: but what are you going to do?  I guess it is worth it if we can make the fat cats fatter
# 38: Don BlankenshipThe Ozarks
# 39: Won't need to buy any pens for a while
# 40: I bought a couple of these for my smaller ambulance corp and they work great
# 41: They last pretty long for the harsh use they go through, the ink doesn't wash off with rain or water, and they even seem to write well in harsh conditions
# 42: We use them to write orders for food in our restaurant
# 43: I bought these to write notes on Christmas cards but did not like them
# 44: The ink is very scant and light colored
# 45: They won't win any beauty contests, but they do put ink on paper, and they do it cheaply
# 46: &#34;  You get items for the price you pay
# 47: good price
# 48: no more to say about this pen
# 49: (one being not having working pen handy when needed) This product has solved that problem
# 50: Can you imagine that these 36 ball pen is only $3
# 51: It's true! What else could cause them to disappear? I think they're forming a colony somewhere in the house, I just hope they don't make a move to take over
# 52: Well, while these pens are very inexpensive they truly do work really well
# 53: For you pen chewers out there you can chew away, and always have another in the box you can lend out without getting those looks (you know what I'm talking about)
# 54: Everyday pens for everyday people
# 55: very true
# 56: used them during a graduation party for the guests
# 57: So many pens at such a good price
# 58: America's favorite pen sold in the HUGE pack!  Great for that office or desk that can never seem to find a pen (like mine)
# 59: Purchased on Nov
# 60: 29th 2012
# 61: I buy a big box of pens and keep some at home, in kitchen, by computer, books, in my bag, a few to give and forget aboutwhen someone asks to "borrow a pen",
# 62: Rate this: Hot
# 63: Pens worked fine
# 64: Grade: B, or Four Stars!
# 65: Go Bic Go
# 66: Good writing pen, use in the office daily, would purchase again
# 67: Cheap is cheap
# 68: Great price, came quickly - so many pens leftover from my project (handing them out at a booth) that I'll be set for pens for a while :)
# 69: These guys are just what I need and the work great
# 70: I think my cat is stealing them
# 71: I got these for a steal on Amazon sometime after Thanksgiving
# 72: Overall, I love these, and I will probably buy a million more of them in my lifetime
# 73: These pens were ordered for our church
# 74: This ten pack is a great value
# 75: Pens write well and are a good value
# 76: Just goto walmart
# 77: its annoying when every other pen does not work
# 78: Very good pens, inexpensive, BIC quality, perfect for office or school, long lasting (takes one and a half lifes to run out of ink)
# 79: 6 (7 if you round) cents a pen
# 80: Even if you lost a pen every few days there's enough here to keep you happy for a while
# 81: I like that Stic Ball pen
# 82: It still feels about the same as the old barrels
# 83: Went back
# 84: Checked Amazon and of course the had them
# 85: I keep them around the house for many different uses
# 86: Warning: if you have a ton of pens, people will just steal them quicker
# 87: Don't tape them to spoons
# 88: That ish is tackyOh, and Gloria will chew the pen caps off no matter what
# 89: gross
# 90: Lots of pens for very cheap
# 91: This was an essential classroom item because I am always losing pens! Great buy!
# 92: The package contained 10 pens
# 93: So few other companies can produce such a consistent pen
# 94: These pens will rock your socks
# 95: You can even fling the pen caps! I love these pens but whatever you do, don't put them in the freezer
# 96: Should've bought post-it notes with them
# 97: I'm happy with the purchase
# 98: I bought a box of these to keep in our kitchen drawer and they are perfect for everyday use
# 99: Used them for a baby shower
# 100: Will definitely order again for other events as they disappear quickly
# 101: They're cheap pens and they write
# 102: Great pens
# 103: These pens are kind of my standard dependable pens
# 104: These would be great for any environment that consumes a lot of pens
# 105: Good stuff
# 106: Definitely recommended if you have cashiers at work who chew through pens at an astonishing rate
# 107: Nothing like writing out a character and looking at it and realizing that half the lines didn't make a mark
# 108: I am making sporadic edits to a paper with these pieces of trash and they can't even make it from the top of the page to the bottom
# 109: I see a lot of positive reviews listing them as "cheap" and that's one thing I agree with
# 110: They seem to dry/clog up instantly, and it is impossible to maintain a train of thought with there constant ineptitude, grinding the gears to a halt
# 111: There are a lot of places these pens can be shoved, but they only belong in one dark, smelly hole--and it ain't a landfill
#
# Cluster 2:
# 1: Best little pen I ever had
# 2: I'm sure every one has used normal bic pens before, they are exactly the same as the one you normally used
# 3: They will always write on the paper! I can't tell you how many pens I've got that didn't write on the paper
# 4: Indeed, as another reviewer has stated, these pens have been around for almost ever
# 5: This is a pen we have used for several years
# 6: What can one say about these pens? They're about the most basic pens imaginable
# 7: ink came first time the pen was used
# 8: I used them at work and they almost always worked
# 9: The best pen I have ever bought, still use today, my coworkers steal these all the time
# 10: I use these pens all the time, so I am used to how they write
# 11: i always use bic pens because i know they will work
# 12: These BICs are my favorite pens to use, even if they aren't too fancy
# 13: I needed pens for work as mine are always being stolen
# 14: Didn't like it at first but had to adjust after using so many 'bad' pens
# 15: They were the best pens I have ever used
# 16: Lots of pens that can be used for a life time, but
# 17: I love these pens: I can pull a pen out of my pocket, and have it work
# 18: Will definitely purchase again when they all disppear as pens often do
#
# Cluster 3:
# 1: And the price is right
# 2: Cost of items together was $5
# 3: 94  shipping and handling is $5
# 4: Good quality, and good price
# 5: recommended for the price
# 6: They are good for the price
# 7: Good pens and the price is right
# 8: They are very functional for the price
# 9: Good price
# 10: Good purchase
# 11: Price was good
#
# Cluster 4:
# 1: They normal everyday pens
# 2: The pen works fine
# 3: Anyway, these pens work great
# 4: Lots of pens that write very smooth
# 5: These pens are blue
# 6: These pens are great
# 7: good pens
# 8: Maybe half of these pens worked
# 9: These are good pens
# 10: These pens are miserable
#
# Cluster 5:
# 1: Recommended
# 2: Ann
# 3: Awesome
# 4: held up well
# 5: Otherwise, they're perfect!
# 6: word
# 7: Go get it!
# 8: Completeley recommended
# 9: they explode!
#
# Cluster 6:
# 1: A bic cheapie is just that
# 2: Turns out that they also write well
# 3: Second, they actually write
# 4: but that is for another review)
# 5: They write well
# 6: Sometimes they work, sometimes they don't
# 7: They write the same as always, too
# 8: They didn't have them
#
# Cluster 7:
# 1: The design is simple and the cap nicely fits both the ink-side the end-side
# 2: Some pen caps don't really fit the end, so you end up losing the cap
# 3: There isn't much to say about these pens, but the cap being able to fit nicely at the end is a plus
# 4: They're light and come with a cap
# 5: The caps were extremely hard to pull off
# 6: The caps go on and off easily with minimal force
# 7: The clip on the caps however make it hard to attach to the lapel or shirt
# 8: good  pens don't love how ya have to pull off the cap instead of click it open but they write well
#
# Cluster 8:
# 1: Bic Pens: from plain (like these) to "fancy", they write, they write, they write -- they are inexpensive, seem to last a looong time, and create GREAT multiple copies because you press em as hard as you want and they write, they write, they write
# 2: I think we've all used these pens for thousands of years, or so it seems!  This is usually one product on which you can count, to not leak all over the place and still write nicely, and for a long time
# 3: I always carry at least two or three packs of these pens with me as invariably, sure as the sun rises, there will be at least one or two kids who forgot their pen or pencil (I always keep several packages of pencils too
# 4: Isn't that what really counts at the end of the day?One minor complaint I have about these pens is that the caps tend to crack if you put them on tightly
# 5: I like the new design and how comfortable they are to write with, but only annoyance is that the caps are SO hard to pull off initially!!  I had to keep twisting and tugging on the caps of all of the pens I've used to far
# 6: So why buy a box of 60 pens, when it takes forever just to use up a single pen?There are lots of reasons, the biggest being the well known fact that once you set a pen down and look away they grow legs and walk off
# 7: I would say that there are maybe 1-2 duds per pack of 60, but it was the cheapest pen I could find online, and much more reliable than freebie promotional pens
# 8: So, the Bic Round Stick Pen Medium Point is a nice little pen!They&#8217;re not fancy, but I was tired of paying $4 for a 2-pen set from Walgreens/CVS/The Local Grocer and such and decided to go ahead and try these as they came 60 in a box&#8230; And so basically for pennies on the dollar I have enough pens that should last myself and my relatives (as they always seem to borrow my work supplies&#8230;) well throughout the year!They work fine, come with caps and so far have not bled out in my bag like some other cheaper pens of the past
# 9: So, if you just want something to write with that doesn&#8217;t have to come with the bells and whistles of a personalized gold pen, or say a calligraphy pen set, then I think anyone would be satisfied with this offering from the folks at Bic
# 10: five stars for the price, i got them very cheap;  with four  kids that use pens often  and loose them even more often the price was awesome; will be buying more later
# 11: I LOVE LOVE LOVE these! This is my Second Order of these which I have placed! When I find something that works as nice and well as These Do, I am a Very Happy Camper! These are really Good Quality Pens and they last! I have really gotten tired of purchasing pens that run out of ink, with very little use
# 12: I would recommend these pens to anyone who journals, does a lot of writing, or simply needs a pen that is Reliable and great to use! I would have rated these a TEN if there were more stars! Thanks BIC and AMAZON! These were a Great Deal and well worth purchasing!
# 13: I love the fact that 10 pens allows several throughout the house so they're always available when you need it - especially by the phones with a pad
# 14: Thus, the cheaply made pen is purchased at an inflated rate, performs cheaply, and then makes it's most prominent impact on the world--not as a writing device, but as another poisonous piece of plastic, sent to join a landfill or float in an ocean: either way, rotting the earth
# 15: The Bic Round Stic pen is the cancer that keeps on giving; I wouldn't wish this junk product on my worst enemy, and I encourage anyone interested in giving this shameful company any money for this, or another, disposable piece of garbage to strongly reconsider and fork up the extra dough to purchase something that is made with actual quality
# 16: If you want to have enough of a nice normal no fuss pen that writes smoothly to get through the zombie apocalypse, if you need to get a crowd jotting things down or if you have to keep a stash of pens because you are surrounded by office supplies thieves then this is the affordable pack of lovely blue pens for you
#
# Cluster 9:
# 1: These do not work well, cheaply made
# 2: Does not bleed
# 3: Wrote smoothly, color good, no flaws
# 4: So far, not a single one that doesn't write on first try
# 5: Forth, they do no leak
# 6: And finally, they are not unpleasant to write with
# 7: They do not leak all over the place and smudge
# 8: Not too fine and not too thick
# 9: Not as good as the Cristal pens, but decent
#
# Cluster 10:
# 1: We are sure to reorder this product
# 2: I was disappointed in my purchase
# 3: I would buy again and recommend to others
# 4: 00, well you bet I love the price
# 5: If you're like me and constantly misplace pens, this is the product for you
# 6: Why on earth?  Bic, you need to come back home to make these
# 7: Be that as it may, I certainly can recommend these things
# 8: Everyone has heard of the "You get what you pay for" saying before
# 9: You get what you pay for
# 10: Now I only want to use this one
# 11: I would not suggest buying this product
# 12: would buy again and again
# 13: I recomend this product
# 14: I recommend you buy
#
# Cluster 11:
# 1: I'm a teacher of Music Technology and there's always kids who come to class without anything to write with
# 2: I personally don't mind  using them, I live with a few people in my house and my pens tend to get lost  quite often
# 3: The grandchildren were very happy to receive them just before school started
# 4: I substitute teach which means I can be in a 3rd grade class one day and in an advanced high school class the next
# 5: I have also noted that some classes and some students will actually try to take advantage of a substitute teacher and their third favorite request the instant the bell rings is "can I go to my locker
# 6: As an additional advantage, I do not mind writing short notes with them myself, and I am one of those people who are constantly misplacing pens all over the house and at my desk
# 7: I gave these to friends in a Nursing Home to write their life stories in!  Those who are writing their stories are having a good time remimicing
# 8: These pens will serve your check book well (does anyone still use those things? I do, but I'm old school like that), take great notes in school, and scribble a quick note at your desk without fuss
# 9: This is great school supplies value for Middle School and High School students who need pens but sometimes lose them in their daily shuffle
# 10: What a good deal, with prime! Enough pens to keep my volleyball team writing away on their statistics sheets for a couple season, hopefully
# 11: Great many for the price and great for classroom use! My students are always excited to get to use a pen
# 12: These pens are the best!  They last a long time, too!  I will be using them mostly for school and my business
# 13: They write well enough for daily needs and if your work environment is anything like mine you'll start to find your lost pens all over the place
# 14: I use them in my classroom (I teach high school) as they are cheaper than most pencils and pens out there
#
# Cluster 12:
# 1: If you're into blue ball point pens, this is where its at
# 2: Works fine most of the time, blobs out ink other times, but hey, GREAT PRICE, and I've lost half of them already, so who cares?
# 3: The color is almost a pink instead of a nice red
# 4: This red pen is SWEET! would highly recommond to someone looking for this, only downside is it could be  bigger~
# 5: These pens are easy to handle, write well, and come in a nice shade of blue
# 6: these bic pens always work the best and the blue was just cheaper but is more vibrant color so works out well when signing paperwork
# 7: The pens write well and are a good size (not too big and not too small)
# 8: They have a plain, cylindrical body, a thoroughly unsophisticated plastic cap, and the whole assembly is the same color as the ink contained within
# 9: Good Value, 60 smooth writing smudge free ink pens in a lightweight barrel with a removable cap
# 10: Overall a good buy, although for some reason the black was not available which is what most people like, but the blue is fine, too
# 11: i was needing some basic  ink pens the bic did the trick  they are good ink pens  if you need basic writeing pens theses pen,s will do it
# 12: They taste great with a little garlic butter and tomato sauce over pasta
# 13: BIC round Stic black 36 pens Medium point
# 14: They're basic and blue which is what you expect when you're buying these
# 15: We all are familiar with the Bic round stic pens, with the white barrel, medium or fine points
# 16: It says white barrel in the description, but I hoped to get this new color
# 17: The pen now comes in a clear blue tinted barrel so you can see the ink inside, and it looks more interesting than the traditional white
# 18: The Cristal pens have a wider point or something, even though these are both labeled as medium points
# 19: If you want a basic blue ballpoint, this is it
# 20: Also had them in black and red, so ordered 2 blues and one black and one red
# 21: They are black ink pens that I love to use when writing down things
# 22: These pens are fine if used sooner else it gets harder and a little rough to use
# 23: Unless you prefer black ink, then keep moving (but I am sure BIC makes a lovely black pen as well)
# 24: These pens are awesome! They feel great on the hand (male) and the ink isn't too fat nor too thin
#
# Cluster 13:
# 1: I ended up throwing out
# 2: I got them at $4
# 3: I'm glad I found them
# 4: Perhaps, they just can't take the owner!Anyway, I got these in bulk
# 5: However, I noticed that they're now made in Mexico
# 6: I never know
# 7: I forgot my pen
# 8: I couldn't ask for more!
# 9: I threw them away
# 10: Bringing me joy where there once was stress, thank you!
# 11: Luckily I did
# 12: Wish they came in green, too
# 13: I somehow managed to lose them all lol
# 14: I recommend them
# 15: I like it a lot
# 16: Everyone in my office like it
#
# Cluster 14:
# 1: i use these for ccdw classes and havent had a problem yet
# 2: Well, after losing money on pens that I bought in the 12pk and handed out but were never returned, I began to use my head instead of my purse
# 3: which often happens, I am not out a lot of money and they are less likely to steal them as they do not really look all that cool nor do they have a lot of whistles and bells on them
# 4: Like another reviewer here, I am not all that happy about these not being manufactured in this country anymore and think it is a shame
# 5: Excellent product, quality, nice-looking and i dont have any bad comment for this product, it just what I was looking for
# 6: I obviously have not tested all 60 of them, but all the ones I have used so far have made nice, smooth, even lines
# 7: you never know when you need a pen or could lend a pen
# 8: Can't go wrong with these!  Love these ball point pens, they work great, never have any issues, and for the price it is amazing
# 9: i have not had the chance to use these pens yet but i am sure i will not be disappointed
# 10: But to hand out to clients that will not return, it's perfect, that was we don't lose our better pens
# 11: There's not much to say about these, they're pens, right?  They last quite a while, they store well, and I like how they write
# 12: If you don't use them for several months, you'll find that several pens do not actually write at all and you will need to throw them away
# 13: I can loan them out and if they don't come back to me I am not out alot of money
# 14: cant beat this price for these pins! I go through a lot of pins at work and these have never been an issue for me
# 15: I have not had any "duds" as you get sometimes with generic brands
# 16: What's worse is that once one of these pestilent pens calls it quits, there's nothing you can do with the abomination except throw it away
# 17: Gooeydoo Books never filled this order: I AM STILL WAITING FOR A CREDIT/REFUND TO MY ACCOUNT
# 18: Meanwhile, I would eschew any dealings with this vendor: They do NOT respond to e-mails! I am surprised AMAZON uses them
#
# Cluster 15:
# 1: 17 almost the cost of the items which are Bic pens
# 2: I bought this pens to be used as &#34;expendables&#34; actually, and they really fit thr bill
# 3: The price for these pens can't be beat
# 4: I couldn't believe the low price for this bulk box of ink pens
# 5: Its a Bic pen, but the price is right!  Ive purchased many times!  I use the pens everyday
# 6: I will buy all ball pens in amazon in the future
# 7: I don't like to pay an extreme price for pens but i expect them to work
# 8: The price was very reasonable, and the pens work well
# 9: I willm buy more for the sae or simiolar price in the future
# 10: Good price for the amount of pens you're buying
# 11: I bought a pack of blue pens at an office supply place
# 12: The price of pens was significant reason for my purchase
# 13: I bought these pens in order reach the limit for my free shipping at Amazon
# 14: I bought these to get over the $25 threshold for free shipping
# 15: It was cheaper to buy the pens for $2 than pay $6 shipping on the other item
#
# Cluster 16:
# 1: They write well and last a fair while before drying up
# 2: These write every time, on a variety of surfaces, and last relatively long
# 3: Even the Africans ask for these by name
# 4: I paid less than $5
# 5: They work and does its job
# 6: Other than that, highly recommend!
# 7: There of course is a reason for this
# 8: actually several reasons
# 9: First they are quite inexpensive
# 10: Third they are available anywhere
# 11: They last quite a long time
# 12: Anyway, they write smoothly and get the job done
# 13: They do what they were meant to do
# 14: These BICs have superb action
# 15: Pens just seem to appear &#34;cheap
# 16: Okay lets be serious now
# 17: BIC lives up to their expectation - their slogan is &#34;writes the first time, every time&#34;
# 18: This is a very good deal
# 19: just a lot more of them!
# 20: They are contemporary looking and light
# 21: These fill the bill nicely
# 22: These are just basic pens, nothing special
# 23: If you want something that looks darker or prettier, find something else
# 24: We will order again
# 25: Always looking for the right pen?  This is it
# 26: It also writes like a BIC
# 27: bic is a name to trust
# 28: What more can you ask?
# 29: They do actually write every time for me
# 30: Nothing special whe you look at them but very enjoyable
# 31: For less than $0
# 32: 10/pen, these are absolutely a steal
# 33: I've gone through about 10 of them so far, and they all write smoothly and perfectly
# 34: Being Bic, I've found these to be incredibly reliable with only two going bad
# 35: Very frustrating to use
# 36: Enough for at least 2 years! Smooth and durable
#
# Cluster 17:
# 1: I wasn't looking for the best writing pen so much as I was the best price
# 2: This pen would be great for a teacher/writer/company to buy
# 3: this is a good seller and I will return
# 4: I thank the seller for the fast service and price
# 5: I got the package very fast
# 6: I was really glad that I could receive the package within a short time
# 7: is a joy when you find simple solution to vexing problem in life
# 8: These pens write cleanly, smoothly, are a joy to use,  and getting so many for such a decent price,  is such a gift, thank you so much for this product
# 9: 50? Thank you so much for this nice offer in amazon
# 10: Of course you get a great free flowing, smooth writing pen as always
# 11: If you want a pen (60 of them, even!) that writes good and clean, and is very reliable, buy these!
# 12: long lasting pens,no smudging always perfect the first time and very well constructed
# 13: This Bic pen writes very well and is long lasting
# 14: I was very happy to find out the quality of this pen
# 15: great stuff for kids, for the purchase of school supplies, good quality and excellent service
# 16: As far as pens go, these are perfect for having around when you need one, but don't care when you misplace/lose it
# 17: If you pull a pen from the box, it will write, and it will write smoothly
# 18: I find it to be a great balance, and on top of that they are cheap!
#
# Cluster 18:
# 1: Use em far more often than I use my Parkers (which I also love)
# 2: BUT I like the pen even more
# 3: I've tried all the cheaper pens and nothing are as good as these right here
# 4: They go through a lot of pens - customers take them, bussers toss them, they drop them, etc
# 5: I lose so many pens
# 6: I use these for illustration purposes more than writing
# 7: Not the smoothest pen, nor the most comfortable to hold, but if you can get this at less than a dime per pen, it's a great value
# 8: We were able to buy it for a much cheaper price
# 9: WE don't use expensive pens because they walk away
# 10: Other than that, these are perfectly adequate and the price really can't be beat
# 11: Are there better pens out there? Of course, but they cost a heck of a lot more
# 12: I find the less expensive pens to do an excellent jobs
# 13: I've had more expensive pens that just stop working
# 14: Nice to have a bunch of low cost pens you can depend on!
# 15: I keep losing them though, which makes me have to keep buying more
# 16: But, I think the pen would benefit a lot more if they added a grip to it
# 17: Pens don't come much cheaper than this, and it shows in the quality of the product
#
# Cluster 19:
# 1: comfortable in your hand but i was surprised how well the ink comes out and write, for dirt cheap pens I love the way they look and feel
# 2: If your looking for cheap then this is what you need to get, If your looking for fancy and attractive this is not it for you
# 3: BIC pens are pretty reliable for taking orders and are cheap enough they don't mind putting them down with credit card receipts
# 4: Great cheap item so far every pen i have used has worked first try i would recommend buy this alot of pen for a great cheap price
# 5: I will note that when the company changed the manufacturing location, to save money I presume, I certainly did not see the price of these things, cheap though they  may be, going down any, for us, the consumer
# 6: these bic pens are great pens which come in a neatly designed box i use these pens in my business for customers to sign their receipts and work orders they last and work well
# 7: People lose pens all the time and these are so inexpensive that I don't feel bad constantly giving out new ones like I have to do anyway
# 8: These are your basic every day pens that are so darn cheap you don't much care when they grow their legs and disappear on you
# 9: I manage a small business and have a great need of pens, to save money I was buying cheap pens but luckily got these
# 10: For the price and all I wasn't expecting much but these pens work great right out of the box
# 11: Comfortable to write with and priced cheap enough that losing them isn't too much of a bummer
# 12: While these are not the type of pens you would want to write with for a long period of time, they are a great buy
# 13: Gets two stars because they're cheap and you could leave them out at a business and people wouldn't be very tempted to take them home
#
# Cluster 20:
#
# Cluster 21:
#
# Cluster 22:
#
# Cluster 23:
#
# Cluster 24:
#
# Cluster 25:
#
# Cluster 26:
#
# Cluster 27:
#
# Cluster 28:
#
# Cluster 29:
#
# Cluster 30:
#
# Cluster 31:
#
# Cluster 32:
#
# Cluster 33:
#
# Cluster 34:
#
# Cluster 35:
#
# Cluster 36:
#
# Cluster 37:
#
# Cluster 38:
#
# Cluster 39:
